# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 696s 4us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(265, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 265)               132765
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 265)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2660
# =================================================================
# Total params: 658,469
# Trainable params: 658,469
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='mymodel.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 17s - loss: 1.6184 - accuracy: 0.4052 - val_loss: 1.2644 - val_accuracy: 0.5546
#
# Epoch 00001: val_loss improved from inf to 1.26444, saving model to mymodel.weights.best.hdf5
# Epoch 2/100
#  - 17s - loss: 1.2875 - accuracy: 0.5370 - val_loss: 1.0893 - val_accuracy: 0.6058
#
# Epoch 00002: val_loss improved from 1.26444 to 1.08928, saving model to mymodel.weights.best.hdf5
# Epoch 3/100
#  - 17s - loss: 1.1586 - accuracy: 0.5886 - val_loss: 1.0208 - val_accuracy: 0.6368
#
# Epoch 00003: val_loss improved from 1.08928 to 1.02077, saving model to mymodel.weights.best.hdf5
# Epoch 4/100
#  - 17s - loss: 1.0805 - accuracy: 0.6177 - val_loss: 0.9467 - val_accuracy: 0.6714
#
# Epoch 00004: val_loss improved from 1.02077 to 0.94669, saving model to mymodel.weights.best.hdf5
# Epoch 5/100
#  - 17s - loss: 1.0198 - accuracy: 0.6409 - val_loss: 0.9485 - val_accuracy: 0.6764
#
# Epoch 00005: val_loss did not improve from 0.94669
# Epoch 6/100
#  - 17s - loss: 0.9664 - accuracy: 0.6598 - val_loss: 0.9288 - val_accuracy: 0.6648
#
# Epoch 00006: val_loss improved from 0.94669 to 0.92879, saving model to mymodel.weights.best.hdf5
# Epoch 7/100
#  - 17s - loss: 0.9368 - accuracy: 0.6685 - val_loss: 0.8791 - val_accuracy: 0.6954
#
# Epoch 00007: val_loss improved from 0.92879 to 0.87910, saving model to mymodel.weights.best.hdf5
# Epoch 8/100
#  - 18s - loss: 0.8900 - accuracy: 0.6867 - val_loss: 0.8200 - val_accuracy: 0.7132
#
# Epoch 00008: val_loss improved from 0.87910 to 0.81999, saving model to mymodel.weights.best.hdf5
# Epoch 9/100
#  - 17s - loss: 0.8637 - accuracy: 0.6946 - val_loss: 0.7944 - val_accuracy: 0.7292
#
# Epoch 00009: val_loss improved from 0.81999 to 0.79439, saving model to mymodel.weights.best.hdf5
# Epoch 10/100
#  - 19s - loss: 0.8334 - accuracy: 0.7065 - val_loss: 0.7705 - val_accuracy: 0.7370
#
# Epoch 00010: val_loss improved from 0.79439 to 0.77046, saving model to mymodel.weights.best.hdf5
# Epoch 11/100
#  - 17s - loss: 0.8160 - accuracy: 0.7113 - val_loss: 0.7889 - val_accuracy: 0.7304
#
# Epoch 00011: val_loss did not improve from 0.77046
# Epoch 12/100
#  - 17s - loss: 0.7905 - accuracy: 0.7206 - val_loss: 0.7894 - val_accuracy: 0.7158
#
# Epoch 00012: val_loss did not improve from 0.77046
# Epoch 13/100
#  - 18s - loss: 0.7709 - accuracy: 0.7279 - val_loss: 0.7777 - val_accuracy: 0.7310
#
# Epoch 00013: val_loss did not improve from 0.77046
# Epoch 14/100
#  - 20s - loss: 0.7512 - accuracy: 0.7359 - val_loss: 0.7603 - val_accuracy: 0.7414
#
# Epoch 00014: val_loss improved from 0.77046 to 0.76030, saving model to mymodel.weights.best.hdf5
# Epoch 15/100
#  - 18s - loss: 0.7383 - accuracy: 0.7417 - val_loss: 0.7515 - val_accuracy: 0.7372
#
# Epoch 00015: val_loss improved from 0.76030 to 0.75148, saving model to mymodel.weights.best.hdf5
# Epoch 16/100
#  - 17s - loss: 0.7310 - accuracy: 0.7428 - val_loss: 0.7626 - val_accuracy: 0.7368
#
# Epoch 00016: val_loss did not improve from 0.75148
# Epoch 17/100
#  - 17s - loss: 0.7107 - accuracy: 0.7495 - val_loss: 0.7725 - val_accuracy: 0.7360
#
# Epoch 00017: val_loss did not improve from 0.75148
# Epoch 18/100
#  - 17s - loss: 0.6963 - accuracy: 0.7551 - val_loss: 0.7496 - val_accuracy: 0.7380
#
# Epoch 00018: val_loss improved from 0.75148 to 0.74957, saving model to mymodel.weights.best.hdf5
# Epoch 19/100
#  - 17s - loss: 0.6851 - accuracy: 0.7575 - val_loss: 0.7428 - val_accuracy: 0.7458
#
# Epoch 00019: val_loss improved from 0.74957 to 0.74285, saving model to mymodel.weights.best.hdf5
# Epoch 20/100
#  - 17s - loss: 0.6694 - accuracy: 0.7626 - val_loss: 0.8335 - val_accuracy: 0.7206
#
# Epoch 00020: val_loss did not improve from 0.74285
# Epoch 21/100
#  - 17s - loss: 0.6602 - accuracy: 0.7683 - val_loss: 0.7432 - val_accuracy: 0.7448
#
# Epoch 00021: val_loss did not improve from 0.74285
# Epoch 22/100
#  - 17s - loss: 0.6535 - accuracy: 0.7694 - val_loss: 0.7559 - val_accuracy: 0.7418
#
# Epoch 00022: val_loss did not improve from 0.74285
# Epoch 23/100
#  - 18s - loss: 0.6455 - accuracy: 0.7719 - val_loss: 0.7421 - val_accuracy: 0.7420
#
# Epoch 00023: val_loss improved from 0.74285 to 0.74215, saving model to mymodel.weights.best.hdf5
# Epoch 24/100
#  - 17s - loss: 0.6373 - accuracy: 0.7743 - val_loss: 0.7509 - val_accuracy: 0.7412
#
# Epoch 00024: val_loss did not improve from 0.74215
# Epoch 25/100
#  - 18s - loss: 0.6201 - accuracy: 0.7827 - val_loss: 0.7406 - val_accuracy: 0.7440
#
# Epoch 00025: val_loss improved from 0.74215 to 0.74062, saving model to mymodel.weights.best.hdf5
# Epoch 26/100
#  - 17s - loss: 0.6147 - accuracy: 0.7832 - val_loss: 0.7285 - val_accuracy: 0.7528
#
# Epoch 00026: val_loss improved from 0.74062 to 0.72853, saving model to mymodel.weights.best.hdf5
# Epoch 27/100
#  - 18s - loss: 0.6031 - accuracy: 0.7885 - val_loss: 0.7353 - val_accuracy: 0.7492
#
# Epoch 00027: val_loss did not improve from 0.72853
# Epoch 28/100
#  - 20s - loss: 0.5967 - accuracy: 0.7885 - val_loss: 0.7397 - val_accuracy: 0.7482
#
# Epoch 00028: val_loss did not improve from 0.72853
# Epoch 29/100
#  - 18s - loss: 0.5920 - accuracy: 0.7907 - val_loss: 0.7554 - val_accuracy: 0.7422
#
# Epoch 00029: val_loss did not improve from 0.72853
# Epoch 30/100
#  - 19s - loss: 0.5847 - accuracy: 0.7954 - val_loss: 0.7380 - val_accuracy: 0.7522
#
# Epoch 00030: val_loss did not improve from 0.72853
# Epoch 31/100
#  - 19s - loss: 0.5758 - accuracy: 0.7960 - val_loss: 0.7693 - val_accuracy: 0.7490
#
# Epoch 00031: val_loss did not improve from 0.72853
# Epoch 32/100
#  - 18s - loss: 0.5754 - accuracy: 0.7979 - val_loss: 0.7995 - val_accuracy: 0.7322
#
# Epoch 00032: val_loss did not improve from 0.72853
# Epoch 33/100
#  - 19s - loss: 0.5595 - accuracy: 0.8037 - val_loss: 0.7624 - val_accuracy: 0.7456
#
# Epoch 00033: val_loss did not improve from 0.72853
# Epoch 34/100
#  - 18s - loss: 0.5627 - accuracy: 0.8012 - val_loss: 0.7401 - val_accuracy: 0.7528
#
# Epoch 00034: val_loss did not improve from 0.72853
# Epoch 35/100
#  - 20s - loss: 0.5488 - accuracy: 0.8072 - val_loss: 0.7267 - val_accuracy: 0.7500
#
# Epoch 00035: val_loss improved from 0.72853 to 0.72674, saving model to mymodel.weights.best.hdf5
# Epoch 36/100
#  - 19s - loss: 0.5529 - accuracy: 0.8059 - val_loss: 0.7812 - val_accuracy: 0.7310
#
# Epoch 00036: val_loss did not improve from 0.72674
# Epoch 37/100
#  - 18s - loss: 0.5453 - accuracy: 0.8078 - val_loss: 0.7444 - val_accuracy: 0.7544
#
# Epoch 00037: val_loss did not improve from 0.72674
# Epoch 38/100
#  - 18s - loss: 0.5436 - accuracy: 0.8083 - val_loss: 0.7336 - val_accuracy: 0.7576
#
# Epoch 00038: val_loss did not improve from 0.72674
# Epoch 39/100
#  - 18s - loss: 0.5279 - accuracy: 0.8135 - val_loss: 0.7295 - val_accuracy: 0.7550
#
# Epoch 00039: val_loss did not improve from 0.72674
# Epoch 40/100
#  - 19s - loss: 0.5262 - accuracy: 0.8148 - val_loss: 0.7488 - val_accuracy: 0.7544
#
# Epoch 00040: val_loss did not improve from 0.72674
# Epoch 41/100
#  - 19s - loss: 0.5260 - accuracy: 0.8147 - val_loss: 0.7684 - val_accuracy: 0.7458
#
# Epoch 00041: val_loss did not improve from 0.72674
# Epoch 42/100
#  - 18s - loss: 0.5201 - accuracy: 0.8192 - val_loss: 0.7401 - val_accuracy: 0.7530
#
# Epoch 00042: val_loss did not improve from 0.72674
# Epoch 43/100
#  - 19s - loss: 0.5138 - accuracy: 0.8212 - val_loss: 0.7476 - val_accuracy: 0.7486
#
# Epoch 00043: val_loss did not improve from 0.72674
# Epoch 44/100
#  - 19s - loss: 0.5081 - accuracy: 0.8222 - val_loss: 0.7617 - val_accuracy: 0.7444
#
# Epoch 00044: val_loss did not improve from 0.72674
# Epoch 45/100
#  - 18s - loss: 0.5140 - accuracy: 0.8207 - val_loss: 0.7481 - val_accuracy: 0.7426
#
# Epoch 00045: val_loss did not improve from 0.72674
# Epoch 46/100
#  - 18s - loss: 0.5062 - accuracy: 0.8234 - val_loss: 0.7467 - val_accuracy: 0.7496
#
# Epoch 00046: val_loss did not improve from 0.72674
# Epoch 47/100
#  - 18s - loss: 0.4981 - accuracy: 0.8272 - val_loss: 0.7280 - val_accuracy: 0.7506
#
# Epoch 00047: val_loss did not improve from 0.72674
# Epoch 48/100
#  - 19s - loss: 0.4953 - accuracy: 0.8258 - val_loss: 0.7367 - val_accuracy: 0.7582
#
# Epoch 00048: val_loss did not improve from 0.72674
# Epoch 49/100
#  - 18s - loss: 0.4961 - accuracy: 0.8268 - val_loss: 0.7345 - val_accuracy: 0.7578
# Epoch 00049: val_loss did not improve from 0.72674
# Epoch 50/100
#  - 18s - loss: 0.4911 - accuracy: 0.8296 - val_loss: 0.7631 - val_accuracy: 0.7494
#
# Epoch 00050: val_loss did not improve from 0.72674
# Epoch 51/100
#  - 18s - loss: 0.4825 - accuracy: 0.8302 - val_loss: 0.7469 - val_accuracy: 0.7536
#
# Epoch 00051: val_loss did not improve from 0.72674
# Epoch 52/100
#  - 18s - loss: 0.4811 - accuracy: 0.8334 - val_loss: 0.7435 - val_accuracy: 0.7480
#
# Epoch 00052: val_loss did not improve from 0.72674
# Epoch 53/100
#  - 19s - loss: 0.4830 - accuracy: 0.8312 - val_loss: 0.7498 - val_accuracy: 0.7512
#
# Epoch 00053: val_loss did not improve from 0.72674
# Epoch 54/100
#  - 20s - loss: 0.4775 - accuracy: 0.8339 - val_loss: 0.7647 - val_accuracy: 0.7454
#
# Epoch 00054: val_loss did not improve from 0.72674
# Epoch 55/100
#  - 19s - loss: 0.4791 - accuracy: 0.8328 - val_loss: 0.7681 - val_accuracy: 0.7456
#
# Epoch 00055: val_loss did not improve from 0.72674
# Epoch 56/100
#  - 18s - loss: 0.4691 - accuracy: 0.8364 - val_loss: 0.7468 - val_accuracy: 0.7566
#
# Epoch 00056: val_loss did not improve from 0.72674
# Epoch 57/100
#  - 19s - loss: 0.4667 - accuracy: 0.8387 - val_loss: 0.7541 - val_accuracy: 0.7504
#
# Epoch 00057: val_loss did not improve from 0.72674
# Epoch 58/100
#  - 18s - loss: 0.4622 - accuracy: 0.8395 - val_loss: 0.7594 - val_accuracy: 0.7460
#
# Epoch 00058: val_loss did not improve from 0.72674
# Epoch 59/100
#  - 19s - loss: 0.4637 - accuracy: 0.8387 - val_loss: 0.7861 - val_accuracy: 0.7398
#
# Epoch 00059: val_loss did not improve from 0.72674
# Epoch 60/100
#  - 21s - loss: 0.4626 - accuracy: 0.8396 - val_loss: 0.7775 - val_accuracy: 0.7476
#
# Epoch 00060: val_loss did not improve from 0.72674
# Epoch 61/100
#  - 19s - loss: 0.4598 - accuracy: 0.8414 - val_loss: 0.7538 - val_accuracy: 0.7484
#
# Epoch 00061: val_loss did not improve from 0.72674
# Epoch 62/100
#  - 20s - loss: 0.4583 - accuracy: 0.8406 - val_loss: 0.7495 - val_accuracy: 0.7558
#
# Epoch 00062: val_loss did not improve from 0.72674
# Epoch 63/100
#  - 20s - loss: 0.4538 - accuracy: 0.8441 - val_loss: 0.7793 - val_accuracy: 0.7480
#
# Epoch 00063: val_loss did not improve from 0.72674
# Epoch 64/100
#  - 20s - loss: 0.4576 - accuracy: 0.8404 - val_loss: 0.7606 - val_accuracy: 0.7466
#
# Epoch 00064: val_loss did not improve from 0.72674
# Epoch 65/100
#  - 19s - loss: 0.4465 - accuracy: 0.8450 - val_loss: 0.7765 - val_accuracy: 0.7482
#
# Epoch 00065: val_loss did not improve from 0.72674
# Epoch 66/100
#  - 19s - loss: 0.4408 - accuracy: 0.8496 - val_loss: 0.7695 - val_accuracy: 0.7500
#
# Epoch 00066: val_loss did not improve from 0.72674
# Epoch 67/100
#  - 20s - loss: 0.4444 - accuracy: 0.8471 - val_loss: 0.7706 - val_accuracy: 0.7470
#
# Epoch 00067: val_loss did not improve from 0.72674
# Epoch 68/100
#  - 20s - loss: 0.4441 - accuracy: 0.8481 - val_loss: 0.7579 - val_accuracy: 0.7524
#
# Epoch 00068: val_loss did not improve from 0.72674
# Epoch 69/100
#  - 19s - loss: 0.4322 - accuracy: 0.8508 - val_loss: 0.7691 - val_accuracy: 0.7522
#
# Epoch 00069: val_loss did not improve from 0.72674
# Epoch 70/100
#  - 20s - loss: 0.4375 - accuracy: 0.8480 - val_loss: 0.7786 - val_accuracy: 0.7392
#
# Epoch 00070: val_loss did not improve from 0.72674
# Epoch 71/100
#  - 21s - loss: 0.4371 - accuracy: 0.8510 - val_loss: 0.7427 - val_accuracy: 0.7570
#
# Epoch 00071: val_loss did not improve from 0.72674
# Epoch 72/100
#  - 20s - loss: 0.4297 - accuracy: 0.8542 - val_loss: 0.7781 - val_accuracy: 0.7482
#
# Epoch 00072: val_loss did not improve from 0.72674
# Epoch 73/100
#  - 19s - loss: 0.4326 - accuracy: 0.8498 - val_loss: 0.7661 - val_accuracy: 0.7566
#
# Epoch 00073: val_loss did not improve from 0.72674
# Epoch 74/100
#  - 19s - loss: 0.4310 - accuracy: 0.8507 - val_loss: 0.7619 - val_accuracy: 0.7488
#
# Epoch 00074: val_loss did not improve from 0.72674
# Epoch 75/100
#  - 19s - loss: 0.4219 - accuracy: 0.8558 - val_loss: 0.7623 - val_accuracy: 0.7496
#
# Epoch 00075: val_loss did not improve from 0.72674
# Epoch 76/100
#  - 18s - loss: 0.4222 - accuracy: 0.8547 - val_loss: 0.7501 - val_accuracy: 0.7502
#
# Epoch 00076: val_loss did not improve from 0.72674
# Epoch 77/100
#  - 19s - loss: 0.4289 - accuracy: 0.8556 - val_loss: 0.7703 - val_accuracy: 0.7466
#
# Epoch 00077: val_loss did not improve from 0.72674
# Epoch 78/100
#  - 18s - loss: 0.4157 - accuracy: 0.8573 - val_loss: 0.7548 - val_accuracy: 0.7484
#
# Epoch 00078: val_loss did not improve from 0.72674
# Epoch 79/100
#  - 19s - loss: 0.4201 - accuracy: 0.8572 - val_loss: 0.7530 - val_accuracy: 0.7562
#
# Epoch 00079: val_loss did not improve from 0.72674
# Epoch 80/100
#  - 19s - loss: 0.4276 - accuracy: 0.8551 - val_loss: 0.7643 - val_accuracy: 0.7544
#
# Epoch 00080: val_loss did not improve from 0.72674
# Epoch 81/100
#  - 18s - loss: 0.4226 - accuracy: 0.8565 - val_loss: 0.7846 - val_accuracy: 0.7452
#
# Epoch 00081: val_loss did not improve from 0.72674
# Epoch 82/100
#  - 19s - loss: 0.4153 - accuracy: 0.8586 - val_loss: 0.7474 - val_accuracy: 0.7552
#
# Epoch 00082: val_loss did not improve from 0.72674
# Epoch 83/100
#  - 19s - loss: 0.4197 - accuracy: 0.8572 - val_loss: 0.7445 - val_accuracy: 0.7568
#
# Epoch 00083: val_loss did not improve from 0.72674
# Epoch 84/100
#  - 18s - loss: 0.4118 - accuracy: 0.8580 - val_loss: 0.7649 - val_accuracy: 0.7542
#
# Epoch 00084: val_loss did not improve from 0.72674
# Epoch 85/100
#  - 19s - loss: 0.4164 - accuracy: 0.8568 - val_loss: 0.7485 - val_accuracy: 0.7596
#
# Epoch 00085: val_loss did not improve from 0.72674
# Epoch 86/100
#  - 18s - loss: 0.4113 - accuracy: 0.8602 - val_loss: 0.7503 - val_accuracy: 0.7554
#
# Epoch 00086: val_loss did not improve from 0.72674
# Epoch 87/100
#  - 19s - loss: 0.4078 - accuracy: 0.8612 - val_loss: 0.7469 - val_accuracy: 0.7592
#
# Epoch 00087: val_loss did not improve from 0.72674
# Epoch 88/100
#  - 19s - loss: 0.4004 - accuracy: 0.8639 - val_loss: 0.7693 - val_accuracy: 0.7496
#
# Epoch 00088: val_loss did not improve from 0.72674
# Epoch 89/100
#  - 19s - loss: 0.4060 - accuracy: 0.8619 - val_loss: 0.7802 - val_accuracy: 0.7488
#
# Epoch 00089: val_loss did not improve from 0.72674
# Epoch 90/100
#  - 18s - loss: 0.4058 - accuracy: 0.8612 - val_loss: 0.7783 - val_accuracy: 0.7542
#
# Epoch 00090: val_loss did not improve from 0.72674
# Epoch 91/100
#  - 19s - loss: 0.4017 - accuracy: 0.8642 - val_loss: 0.7638 - val_accuracy: 0.7546
#
# Epoch 00091: val_loss did not improve from 0.72674
# Epoch 92/100
#  - 20s - loss: 0.4040 - accuracy: 0.8621 - val_loss: 0.7655 - val_accuracy: 0.7570
#
# Epoch 00092: val_loss did not improve from 0.72674
# Epoch 93/100
#  - 18s - loss: 0.3999 - accuracy: 0.8633 - val_loss: 0.7747 - val_accuracy: 0.7492
#
# Epoch 00093: val_loss did not improve from 0.72674
# Epoch 94/100
#  - 18s - loss: 0.3991 - accuracy: 0.8646 - val_loss: 0.7643 - val_accuracy: 0.7508
#
# Epoch 00094: val_loss did not improve from 0.72674
# Epoch 95/100
#  - 20s - loss: 0.4013 - accuracy: 0.8641 - val_loss: 0.7387 - val_accuracy: 0.7598
#
# Epoch 00095: val_loss did not improve from 0.72674
# Epoch 96/100
#  - 20s - loss: 0.4066 - accuracy: 0.8605 - val_loss: 0.7615 - val_accuracy: 0.7506
#
# Epoch 00096: val_loss did not improve from 0.72674
# Epoch 97/100
#  - 18s - loss: 0.3931 - accuracy: 0.8634 - val_loss: 0.7851 - val_accuracy: 0.7514
#
# Epoch 00097: val_loss did not improve from 0.72674
# Epoch 98/100
#  - 18s - loss: 0.3904 - accuracy: 0.8674 - val_loss: 0.7707 - val_accuracy: 0.7494
#
# Epoch 00098: val_loss did not improve from 0.72674
# Epoch 99/100
#  - 18s - loss: 0.3903 - accuracy: 0.8697 - val_loss: 0.7728 - val_accuracy: 0.7536
#
# Epoch 00099: val_loss did not improve from 0.72674
# Epoch 100/100
#  - 18s - loss: 0.3927 - accuracy: 0.8668 - val_loss: 0.7935 - val_accuracy: 0.7470
#
# Epoch 00100: val_loss did not improve from 0.72674

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('mymodel.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7458000183105469

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
